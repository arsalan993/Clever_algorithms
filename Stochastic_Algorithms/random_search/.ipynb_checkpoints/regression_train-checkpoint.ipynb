# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
df_ge = pd.read_csv("ge-stock/ge.us.txt")
df_ge.head()
# Out:
#          Date    Open    High     Low   Close   Volume  OpenInt
# 0  1962-01-02  0.6277  0.6362  0.6201  0.6201  2575579        0
# 1  1962-01-03  0.6201  0.6201  0.6122  0.6201  1764749        0
# 2  1962-01-04  0.6201  0.6201  0.6037  0.6122  2194010        0
# 3  1962-01-05  0.6122  0.6122  0.5798  0.5957  3255244        0
# 4  1962-01-08  0.5957  0.5957  0.5716  0.5957  3696430        0

# %%
plt.figure()
plt.plot(df_ge["Open"])
plt.plot(df_ge["High"])
plt.plot(df_ge["Low"])
plt.plot(df_ge["Close"])
plt.title('GE stock price history')
plt.ylabel('Price (USD)')
plt.xlabel('Days')
plt.legend(['Open','High','Low','Close'], loc='upper left')
plt.show()

plt.figure()
plt.plot(df_ge["Volume"])
plt.title('GE stock volume history')
plt.ylabel('Volume')
plt.xlabel('Days')
plt.show()

# %%
print("checking if any null values are present\n", df_ge.isna().sum())

train_cols = ["High","Low","Close"]
df_train, df_test = train_test_split(df_ge, train_size=0.8, test_size=0.2, shuffle=False)
print("Train and Test size", len(df_train), len(df_test))
# scale the feature MinMax, build array
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])
# Out:
# checking if any null values are present
#  Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# dtype: int64
# Train and Test size 11246 2812

# %%
x_t = x_train[:,0:2]
x_t = np.expand_dims(x_t, 2)
y_t = x_train[:,2]

# %%
x_temp = x_test[:,0:2]
x_temp = np.expand_dims(x_temp, 2)
y_temp = x_test[:,2]

# %%
from keras.models import Sequential
from keras.layers import LSTM , Dropout, Dense
from keras import optimizers
# Out:
# Using TensorFlow backend.
# /home/arsalan/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:455: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/arsalan/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:456: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/arsalan/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:457: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/arsalan/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:458: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/arsalan/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:459: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/arsalan/anaconda3/envs/test/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:462: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(150, dropout=0.005, recurrent_dropout=0.005,
                    kernel_initializer='random_uniform',input_shape=(2,1)))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(80,activation='relu'))
lstm_model.add(Dense(1,activation='sigmoid'))
optimizer = optimizers.Adam()
lstm_model.compile(loss='mean_squared_error', optimizer=optimizer)

history = lstm_model.fit(x_t, y_t, epochs=200, verbose=2,
                    shuffle=True,validation_split=0.15)
# Out:
# Train on 9559 samples, validate on 1687 samples
# Epoch 1/200
#  - 2s - loss: 0.0220 - val_loss: 0.0039
# Epoch 2/200
#  - 2s - loss: 9.3409e-04 - val_loss: 0.0021
# Epoch 3/200
#  - 2s - loss: 6.5369e-04 - val_loss: 0.0011
# Epoch 4/200
#  - 2s - loss: 4.4016e-04 - val_loss: 6.7169e-04
# Epoch 5/200
#  - 1s - loss: 2.2906e-04 - val_loss: 5.1116e-04
# Epoch 6/200
#  - 1s - loss: 2.6061e-04 - val_loss: 6.1900e-04
# Epoch 7/200
#  - 1s - loss: 2.1321e-04 - val_loss: 8.8340e-04
# Epoch 8/200
#  - 1s - loss: 2.5636e-04 - val_loss: 7.4292e-04
# Epoch 9/200
#  - 1s - loss: 2.0933e-04 - val_loss: 9.0049e-04
# Epoch 10/200
#  - 1s - loss: 2.1736e-04 - val_loss: 6.0976e-04
# Epoch 11/200
#  - 1s - loss: 1.8892e-04 - val_loss: 8.2167e-04
# Epoch 12/200
#  - 1s - loss: 1.7709e-04 - val_loss: 0.0022
# Epoch 13/200
#  - 1s - loss: 2.3555e-04 - val_loss: 0.0012
# Epoch 14/200
#  - 1s - loss: 2.0211e-04 - val_loss: 7.7480e-04
# Epoch 15/200
#  - 1s - loss: 2.1685e-04 - val_loss: 8.5681e-04
# Epoch 16/200
#  - 1s - loss: 3.1412e-04 - val_loss: 8.2276e-04
# Epoch 17/200
#  - 1s - loss: 1.5813e-04 - val_loss: 8.4958e-04
# Epoch 18/200
#  - 1s - loss: 2.6811e-04 - val_loss: 0.0014
# Epoch 19/200
#  - 1s - loss: 1.7658e-04 - val_loss: 6.5337e-04
# Epoch 20/200
#  - 1s - loss: 1.4195e-04 - val_loss: 9.2989e-04
# Epoch 21/200
#  - 1s - loss: 2.5475e-04 - val_loss: 0.0015
# Epoch 22/200
#  - 1s - loss: 1.8534e-04 - val_loss: 6.5561e-04
# Epoch 23/200
#  - 1s - loss: 1.2977e-04 - val_loss: 4.3684e-04
# Epoch 24/200
#  - 1s - loss: 1.2677e-04 - val_loss: 5.6144e-04
# Epoch 25/200
#  - 1s - loss: 1.0021e-04 - val_loss: 6.2495e-04
# Epoch 26/200
#  - 1s - loss: 3.3964e-04 - val_loss: 5.4000e-04
# Epoch 27/200
#  - 1s - loss: 2.4814e-04 - val_loss: 8.2209e-04
# Epoch 28/200
#  - 1s - loss: 1.6958e-04 - val_loss: 4.4643e-04
# Epoch 29/200
#  - 1s - loss: 1.1973e-04 - val_loss: 9.3733e-04
# Epoch 30/200
#  - 1s - loss: 1.5076e-04 - val_loss: 4.7762e-04
# Epoch 31/200
#  - 1s - loss: 1.8567e-04 - val_loss: 4.5640e-04
# Epoch 32/200
#  - 1s - loss: 1.5676e-04 - val_loss: 7.3721e-04
# Epoch 33/200
#  - 1s - loss: 1.3925e-04 - val_loss: 4.8094e-04
# Epoch 34/200
#  - 1s - loss: 6.7797e-05 - val_loss: 7.3727e-04
# Epoch 35/200
#  - 1s - loss: 2.2082e-04 - val_loss: 0.0011
# Epoch 36/200
#  - 1s - loss: 1.4211e-04 - val_loss: 4.3709e-04
# Epoch 37/200
#  - 1s - loss: 1.1462e-04 - val_loss: 8.8178e-04
# Epoch 38/200
#  - 1s - loss: 9.2315e-05 - val_loss: 4.2147e-04
# Epoch 39/200
#  - 1s - loss: 1.2828e-04 - val_loss: 9.6439e-04
# Epoch 40/200
#  - 1s - loss: 6.6533e-05 - val_loss: 3.8139e-04
# Epoch 41/200
#  - 1s - loss: 1.7464e-04 - val_loss: 5.2081e-04
# Epoch 42/200
#  - 1s - loss: 1.8900e-04 - val_loss: 4.9023e-04
# Epoch 43/200
#  - 1s - loss: 1.5598e-04 - val_loss: 7.6446e-04
# Epoch 44/200
#  - 1s - loss: 1.2239e-04 - val_loss: 5.7738e-04
# Epoch 45/200
#  - 1s - loss: 1.6885e-04 - val_loss: 8.3583e-04
# Epoch 46/200
#  - 1s - loss: 1.5289e-04 - val_loss: 6.9035e-04
# Epoch 47/200
#  - 1s - loss: 1.0348e-04 - val_loss: 4.7975e-04
# Epoch 48/200
#  - 1s - loss: 1.1675e-04 - val_loss: 2.9276e-04
# Epoch 49/200
#  - 1s - loss: 1.1134e-04 - val_loss: 7.7634e-04
# Epoch 50/200
#  - 1s - loss: 1.6901e-04 - val_loss: 5.1655e-04
# Epoch 51/200
#  - 1s - loss: 1.4997e-04 - val_loss: 2.5089e-04
# Epoch 52/200
#  - 1s - loss: 1.3986e-04 - val_loss: 2.9732e-04
# Epoch 53/200
#  - 1s - loss: 1.5058e-04 - val_loss: 2.2936e-04
# Epoch 54/200
#  - 1s - loss: 1.4068e-04 - val_loss: 2.2309e-04
# Epoch 55/200
#  - 1s - loss: 1.4209e-04 - val_loss: 6.4714e-04
# Epoch 56/200
#  - 2s - loss: 1.0213e-04 - val_loss: 4.6891e-04
# Epoch 57/200
#  - 2s - loss: 1.8198e-04 - val_loss: 4.9936e-04
# Epoch 58/200
#  - 2s - loss: 8.1676e-05 - val_loss: 0.0010
# Epoch 59/200
#  - 2s - loss: 9.8974e-05 - val_loss: 2.1079e-04
# Epoch 60/200
#  - 2s - loss: 1.3047e-04 - val_loss: 6.3846e-04
# Epoch 61/200
#  - 2s - loss: 6.7454e-05 - val_loss: 4.3515e-04
# Epoch 62/200
#  - 2s - loss: 1.2542e-04 - val_loss: 3.3787e-04
# Epoch 63/200
#  - 2s - loss: 1.0283e-04 - val_loss: 2.8492e-04
# Epoch 64/200
#  - 2s - loss: 1.1821e-04 - val_loss: 2.5698e-04
# Epoch 65/200
#  - 2s - loss: 1.3312e-04 - val_loss: 5.4633e-04
# Epoch 66/200
#  - 2s - loss: 7.4636e-05 - val_loss: 2.7826e-04
# Epoch 67/200
#  - 2s - loss: 7.7201e-05 - val_loss: 2.4313e-04
# Epoch 68/200
#  - 2s - loss: 1.3118e-04 - val_loss: 3.3626e-04
# Epoch 69/200
#  - 2s - loss: 1.0097e-04 - val_loss: 3.5911e-04
# Epoch 70/200
#  - 2s - loss: 1.2833e-04 - val_loss: 8.2046e-04
# Epoch 71/200
#  - 2s - loss: 9.1149e-05 - val_loss: 3.9278e-04
# Epoch 72/200
#  - 2s - loss: 1.6421e-04 - val_loss: 3.1996e-04
# Epoch 73/200
#  - 2s - loss: 1.0582e-04 - val_loss: 2.7394e-04
# Epoch 74/200
#  - 2s - loss: 9.0738e-05 - val_loss: 2.7475e-04
# Epoch 75/200
#  - 2s - loss: 9.3052e-05 - val_loss: 2.6699e-04
# Epoch 76/200
#  - 2s - loss: 7.0779e-05 - val_loss: 3.7494e-04
# Epoch 77/200
#  - 2s - loss: 6.6963e-05 - val_loss: 2.6519e-04
# Epoch 78/200
#  - 2s - loss: 8.4600e-05 - val_loss: 2.1516e-04
# Epoch 79/200
#  - 2s - loss: 1.1187e-04 - val_loss: 2.9200e-04
# Epoch 80/200
#  - 2s - loss: 7.0624e-05 - val_loss: 2.9023e-04
# Epoch 81/200
#  - 2s - loss: 6.9629e-05 - val_loss: 2.1827e-04
# Epoch 82/200
#  - 2s - loss: 7.6826e-05 - val_loss: 1.5897e-04
# Epoch 83/200
#  - 2s - loss: 6.9407e-05 - val_loss: 2.0403e-04
# Epoch 84/200
#  - 2s - loss: 7.1505e-05 - val_loss: 2.9566e-04
# Epoch 85/200
#  - 2s - loss: 6.4888e-05 - val_loss: 2.1769e-04
# Epoch 86/200
#  - 2s - loss: 7.9643e-05 - val_loss: 3.2656e-04
# Epoch 87/200
#  - 2s - loss: 8.5091e-05 - val_loss: 1.6544e-04
# Epoch 88/200
#  - 2s - loss: 6.6822e-05 - val_loss: 2.7506e-04
# Epoch 89/200
#  - 2s - loss: 6.0407e-05 - val_loss: 6.3173e-04
# Epoch 90/200
#  - 2s - loss: 6.3445e-05 - val_loss: 5.3575e-04
# Epoch 91/200
#  - 2s - loss: 5.7094e-05 - val_loss: 2.4034e-04
# Epoch 92/200
#  - 2s - loss: 6.1908e-05 - val_loss: 2.1467e-04
# Epoch 93/200
#  - 2s - loss: 7.4117e-05 - val_loss: 2.3879e-04
# Epoch 94/200
#  - 2s - loss: 5.9709e-05 - val_loss: 3.1846e-04
# Epoch 95/200
#  - 2s - loss: 7.3015e-05 - val_loss: 3.9041e-04
# Epoch 96/200
#  - 2s - loss: 6.6197e-05 - val_loss: 3.1722e-04
# Epoch 97/200
#  - 2s - loss: 5.4106e-05 - val_loss: 1.4183e-04
# Epoch 98/200
#  - 2s - loss: 5.3505e-05 - val_loss: 3.9748e-04
# Epoch 99/200
#  - 2s - loss: 5.6456e-05 - val_loss: 2.1678e-04
# Epoch 100/200
#  - 2s - loss: 5.9651e-05 - val_loss: 1.8635e-04
# Epoch 101/200
#  - 2s - loss: 5.4634e-05 - val_loss: 2.8094e-04
# Epoch 102/200
#  - 2s - loss: 4.9941e-05 - val_loss: 3.6219e-04
# Epoch 103/200
#  - 2s - loss: 7.3933e-05 - val_loss: 1.9156e-04
# Epoch 104/200
#  - 2s - loss: 5.4973e-05 - val_loss: 4.0898e-04
# Epoch 105/200
#  - 2s - loss: 5.5417e-05 - val_loss: 2.6026e-04
# Epoch 106/200
#  - 2s - loss: 4.9362e-05 - val_loss: 2.2523e-04
# Epoch 107/200
#  - 2s - loss: 4.8948e-05 - val_loss: 5.1762e-04
# Epoch 108/200
#  - 2s - loss: 6.7554e-05 - val_loss: 2.0930e-04
# Epoch 109/200
#  - 2s - loss: 4.8383e-05 - val_loss: 1.6004e-04
# Epoch 110/200
#  - 2s - loss: 4.6461e-05 - val_loss: 2.8651e-04
# Epoch 111/200
#  - 2s - loss: 5.3220e-05 - val_loss: 2.1862e-04
# Epoch 112/200
#  - 2s - loss: 4.8866e-05 - val_loss: 5.0569e-04
# Epoch 113/200
#  - 2s - loss: 4.8899e-05 - val_loss: 3.5359e-04
# Epoch 114/200
#  - 2s - loss: 4.9758e-05 - val_loss: 3.5632e-04
# Epoch 115/200
#  - 2s - loss: 4.3057e-05 - val_loss: 2.1906e-04
# Epoch 116/200
#  - 2s - loss: 4.2090e-05 - val_loss: 3.7421e-04
# Epoch 117/200
#  - 2s - loss: 4.9351e-05 - val_loss: 2.9474e-04
# Epoch 118/200
#  - 2s - loss: 4.4254e-05 - val_loss: 2.4790e-04
# Epoch 119/200
#  - 2s - loss: 4.7627e-05 - val_loss: 3.9340e-04
# Epoch 120/200
#  - 2s - loss: 4.9452e-05 - val_loss: 4.6623e-04
# Epoch 121/200
#  - 2s - loss: 4.7411e-05 - val_loss: 3.7593e-04
# Epoch 122/200
#  - 2s - loss: 4.3136e-05 - val_loss: 3.8027e-04
# Epoch 123/200
#  - 2s - loss: 4.3951e-05 - val_loss: 5.1943e-04
# Epoch 124/200
#  - 2s - loss: 5.1194e-05 - val_loss: 3.6057e-04
# Epoch 125/200
#  - 2s - loss: 4.2778e-05 - val_loss: 3.8817e-04
# Epoch 126/200
#  - 2s - loss: 4.4326e-05 - val_loss: 2.6612e-04
# Epoch 127/200
#  - 2s - loss: 5.2134e-05 - val_loss: 2.9959e-04
# Epoch 128/200
#  - 2s - loss: 4.4746e-05 - val_loss: 3.0482e-04
# Epoch 129/200
#  - 2s - loss: 4.3133e-05 - val_loss: 2.3671e-04
# Epoch 130/200
#  - 2s - loss: 4.3944e-05 - val_loss: 1.8382e-04
# Epoch 131/200
#  - 2s - loss: 4.0923e-05 - val_loss: 3.1327e-04
# Epoch 132/200
#  - 2s - loss: 4.1547e-05 - val_loss: 2.5681e-04
# Epoch 133/200
#  - 2s - loss: 4.1851e-05 - val_loss: 2.5473e-04
# Epoch 134/200
#  - 2s - loss: 4.8259e-05 - val_loss: 2.3338e-04
# Epoch 135/200
#  - 2s - loss: 3.7288e-05 - val_loss: 2.6597e-04
# Epoch 136/200
#  - 2s - loss: 4.6764e-05 - val_loss: 4.5346e-04
# Epoch 137/200
#  - 2s - loss: 4.2496e-05 - val_loss: 2.5136e-04
# Epoch 138/200
#  - 2s - loss: 5.2549e-05 - val_loss: 2.6933e-04
# Epoch 139/200
#  - 2s - loss: 4.1290e-05 - val_loss: 1.9702e-04
# Epoch 140/200
#  - 2s - loss: 4.0809e-05 - val_loss: 2.6411e-04
# Epoch 141/200
#  - 2s - loss: 3.6421e-05 - val_loss: 3.0896e-04
# Epoch 142/200
#  - 2s - loss: 4.0537e-05 - val_loss: 2.7370e-04
# Epoch 143/200
#  - 2s - loss: 3.5486e-05 - val_loss: 3.5127e-04
# Epoch 144/200
#  - 2s - loss: 5.2813e-05 - val_loss: 2.3939e-04
# Epoch 145/200
#  - 2s - loss: 4.9332e-05 - val_loss: 3.2859e-04
# Epoch 146/200
#  - 2s - loss: 4.3074e-05 - val_loss: 3.6794e-04
# Epoch 147/200
#  - 2s - loss: 3.5893e-05 - val_loss: 5.4719e-04
# Epoch 148/200
#  - 2s - loss: 4.5263e-05 - val_loss: 2.5362e-04
# Epoch 149/200
#  - 2s - loss: 3.9717e-05 - val_loss: 3.0195e-04
# Epoch 150/200
#  - 2s - loss: 4.7931e-05 - val_loss: 2.6607e-04
# Epoch 151/200
#  - 2s - loss: 4.1179e-05 - val_loss: 1.2839e-04
# Epoch 152/200
#  - 2s - loss: 3.7027e-05 - val_loss: 1.8409e-04
# Epoch 153/200
#  - 2s - loss: 4.1987e-05 - val_loss: 4.2794e-04
# Epoch 154/200
#  - 2s - loss: 4.1339e-05 - val_loss: 4.0157e-04
# Epoch 155/200
#  - 2s - loss: 3.9330e-05 - val_loss: 3.3343e-04
# Epoch 156/200
#  - 2s - loss: 3.6718e-05 - val_loss: 2.3850e-04
# Epoch 157/200
#  - 2s - loss: 4.4606e-05 - val_loss: 2.4969e-04
# Epoch 158/200
#  - 2s - loss: 4.3231e-05 - val_loss: 2.0708e-04
# Epoch 159/200
#  - 2s - loss: 4.6380e-05 - val_loss: 2.5322e-04
# Epoch 160/200
#  - 2s - loss: 4.3032e-05 - val_loss: 4.0222e-04
# Epoch 161/200
#  - 2s - loss: 4.4082e-05 - val_loss: 2.2612e-04
# Epoch 162/200
#  - 2s - loss: 3.5915e-05 - val_loss: 5.4405e-04
# Epoch 163/200
#  - 2s - loss: 3.8740e-05 - val_loss: 1.6067e-04
# Epoch 164/200
#  - 1s - loss: 3.9204e-05 - val_loss: 2.4360e-04
# Epoch 165/200
#  - 1s - loss: 3.8872e-05 - val_loss: 4.7979e-04
# Epoch 166/200
#  - 1s - loss: 3.4819e-05 - val_loss: 3.4586e-04
# Epoch 167/200
#  - 1s - loss: 4.3813e-05 - val_loss: 4.7549e-04
# Epoch 168/200
#  - 1s - loss: 3.7307e-05 - val_loss: 1.7076e-04
# Epoch 169/200
#  - 1s - loss: 3.3574e-05 - val_loss: 1.9860e-04
# Epoch 170/200
#  - 1s - loss: 4.1323e-05 - val_loss: 3.8236e-04
# Epoch 171/200
#  - 1s - loss: 3.4137e-05 - val_loss: 2.1824e-04
# Epoch 172/200
#  - 1s - loss: 3.2392e-05 - val_loss: 2.1448e-04
# Epoch 173/200
#  - 1s - loss: 3.1890e-05 - val_loss: 3.5285e-04
# Epoch 174/200
#  - 1s - loss: 4.1910e-05 - val_loss: 5.0950e-04
# Epoch 175/200
#  - 1s - loss: 5.0446e-05 - val_loss: 4.3130e-04
# Epoch 176/200
#  - 1s - loss: 3.8186e-05 - val_loss: 2.1500e-04
# Epoch 177/200
#  - 1s - loss: 3.2864e-05 - val_loss: 1.9750e-04
# Epoch 178/200
#  - 1s - loss: 3.2099e-05 - val_loss: 4.4400e-04
# Epoch 179/200
#  - 1s - loss: 3.3989e-05 - val_loss: 2.7846e-04
# Epoch 180/200
#  - 1s - loss: 3.9995e-05 - val_loss: 3.7049e-04
# Epoch 181/200
#  - 1s - loss: 3.6164e-05 - val_loss: 2.8932e-04
# Epoch 182/200
#  - 1s - loss: 3.7409e-05 - val_loss: 2.9907e-04
# Epoch 183/200
#  - 1s - loss: 3.5250e-05 - val_loss: 2.3571e-04
# Epoch 184/200
#  - 1s - loss: 3.7269e-05 - val_loss: 2.7477e-04
# Epoch 185/200
#  - 1s - loss: 3.3269e-05 - val_loss: 1.7217e-04
# Epoch 186/200
#  - 1s - loss: 3.8122e-05 - val_loss: 1.7272e-04
# Epoch 187/200
#  - 1s - loss: 3.3512e-05 - val_loss: 1.7735e-04
# Epoch 188/200
#  - 1s - loss: 3.8775e-05 - val_loss: 1.8940e-04
# Epoch 189/200
#  - 1s - loss: 3.9403e-05 - val_loss: 1.8798e-04
# Epoch 190/200
#  - 1s - loss: 3.7604e-05 - val_loss: 3.4537e-04
# Epoch 191/200
#  - 1s - loss: 2.9283e-05 - val_loss: 2.7294e-04
# Epoch 192/200
#  - 1s - loss: 3.5467e-05 - val_loss: 1.9528e-04
# Epoch 193/200
#  - 1s - loss: 4.0035e-05 - val_loss: 3.3789e-04
# Epoch 194/200
#  - 1s - loss: 3.6967e-05 - val_loss: 2.6447e-04
# Epoch 195/200
#  - 1s - loss: 3.2783e-05 - val_loss: 3.5539e-04
# Epoch 196/200
#  - 1s - loss: 3.0326e-05 - val_loss: 1.7811e-04
# Epoch 197/200
#  - 1s - loss: 3.5111e-05 - val_loss: 1.7857e-04
# Epoch 198/200
#  - 1s - loss: 3.2375e-05 - val_loss: 2.4455e-04
# Epoch 199/200
#  - 1s - loss: 2.9442e-05 - val_loss: 2.3434e-04
# Epoch 200/200
#  - 1s - loss: 4.3498e-05 - val_loss: 1.7441e-04

# %%
predictions = lstm_model.predict(x_temp)

# %%
plt.figure()
plt.plot(y_temp)
plt.plot(predictions)
plt.show()

# %%
np.savetxt("test_data.csv", x_test, delimiter=",")

# %%
lstm_model.save("regression.h5")
